# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
data = pd.read_csv('bridge_digital_twin_dataset.csv')

# %%
data.head()
# Out:
#              Timestamp  Strain_microstrain  Deflection_mm  Vibration_ms2  \
# 0  2023-01-01 00:00:00                 NaN      12.663104       1.275955
# 1  2023-01-01 00:01:00          599.936448      12.235297       0.716857
# 2  2023-01-01 00:02:00          573.878472      12.447144       0.834753
# 3  2023-01-01 00:03:00          550.457302      12.554883       1.004917
# 4  2023-01-01 00:04:00          572.829960      12.598818       1.176253
#
#    Tilt_deg  Displacement_mm  Crack_Propagation_mm  Corrosion_Level_percent  \
# 0  0.587340        22.576518             -0.000083                 0.002910
# 1  0.657122        21.202649              0.000092                 0.004601
# 2  0.615011              NaN             -0.000377                 0.005115
# 3  0.617999        21.551945             -0.000646                 0.005505
# 4  0.633534        21.711292              0.000247                -0.003415
#
#    Cable_Member_Tension_kN  Bearing_Joint_Forces_kN  ...  \
# 0               404.394906               233.052345  ...
# 1               367.821051               237.545735  ...
# 2               402.393742               239.164832  ...
# 3               356.024238               237.645586  ...
# 4               413.338280               232.310381  ...
#
#    Soil_Saturation_percent  Landslide_Ground_Movement  \
# 0                 9.888758                        0.0
# 1                 9.920331                        0.0
# 2                      NaN                        0.0
# 3                43.526026                        0.0
# 4                44.138185                        0.0
#
#    Simulated_Slope_Displacement_mm  High_Winds_Storms  \
# 0                         0.022592                0.0
# 1                         0.014647                0.0
# 2                         0.000000                0.0
# 3                         0.000000                0.0
# 4                         0.000000                0.0
#
#    Simulated_Wind_Load_Pressure_kPa  Abnormal_Traffic_Load_Surges  \
# 0                          0.211946                           0.0
# 1                          0.231188                           0.0
# 2                          0.199192                           0.0
# 3                          0.198359                           0.0
# 4                          0.188110                           0.0
#
#    Simulated_Localized_Stress_Index  Energy_Harvesting_Potential_W  \
# 0                          0.215354                       0.081403
# 1                          0.218747                       0.107097
# 2                          0.213449                       0.141938
# 3                          0.208190                       0.192431
# 4                          0.261240                       0.261609
#
#    Estimated_Repair_Cost_USD_incremental  Carbon_Footprint_tCO2e_incremental
# 0                               1.343588                            0.001348
# 1                               1.397207                            0.001299
# 2                               1.318876                            0.001378
# 3                               1.351773                            0.001379
# 4                                    NaN                            0.001267
#
# [5 rows x 54 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43200 entries, 0 to 43199
# Data columns (total 54 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Timestamp                              43200 non-null  object
#  1   Strain_microstrain                     41379 non-null  float64
#  2   Deflection_mm                          41467 non-null  float64
#  3   Vibration_ms2                          41478 non-null  float64
#  4   Tilt_deg                               41447 non-null  float64
#  5   Displacement_mm                        41473 non-null  float64
#  6   Crack_Propagation_mm                   41494 non-null  float64
#  7   Corrosion_Level_percent                41531 non-null  float64
#  8   Cable_Member_Tension_kN                41459 non-null  float64
#  9   Bearing_Joint_Forces_kN                41515 non-null  float64
#  10  Fatigue_Accumulation_au                41496 non-null  float64
#  11  Modal_Frequency_Hz                     41481 non-null  float64
#  12  Temperature_C                          41457 non-null  float64
#  13  Humidity_percent                       41417 non-null  float64
#  14  Wind_Speed_ms                          41474 non-null  float64
#  15  Wind_Direction_deg                     41432 non-null  float64
#  16  Precipitation_mmh                      41513 non-null  float64
#  17  Water_Level_m                          41513 non-null  float64
#  18  Seismic_Activity_ms2                   41507 non-null  float64
#  19  Solar_Radiation_Wm2                    41472 non-null  float64
#  20  Air_Quality_Index_AQI                  41461 non-null  float64
#  21  Soil_Settlement_mm                     41502 non-null  float64
#  22  Vehicle_Load_tons                      41444 non-null  float64
#  23  Traffic_Volume_vph                     41456 non-null  float64
#  24  Pedestrian_Load_pph                    41473 non-null  float64
#  25  Impact_Events_g                        41482 non-null  float64
#  26  Dynamic_Load_Distribution_percent      41539 non-null  float64
#  27  Axle_Counts_pmin                       41500 non-null  float64
#  28  Structural_Health_Index_SHI            41500 non-null  float64
#  29  Anomaly_Detection_Score                41494 non-null  float64
#  30  Energy_Dissipation_au                  41506 non-null  float64
#  31  Acoustic_Emissions_levels              41479 non-null  float64
#  32  Visual_Analysis_Defect_Score           41465 non-null  float64
#  33  Electrical_Resistance_ohms             41454 non-null  float64
#  34  Bridge_Mood_Meter                      41490 non-null  object
#  35  Localized_Strain_Hotspot               41446 non-null  float64
#  36  Vibration_Anomaly_Location             9045 non-null   object
#  37  SHI_Predicted_24h_Ahead                41538 non-null  float64
#  38  SHI_Predicted_7d_Ahead                 41554 non-null  float64
#  39  SHI_Predicted_30d_Ahead                41462 non-null  float64
#  40  Probability_of_Failure_PoF             41456 non-null  float64
#  41  Maintenance_Alert                      41504 non-null  float64
#  42  Flood_Event_Flag                       41457 non-null  float64
#  43  Simulated_Water_Flow_m3s               41494 non-null  float64
#  44  Soil_Saturation_percent                41453 non-null  float64
#  45  Landslide_Ground_Movement              41435 non-null  float64
#  46  Simulated_Slope_Displacement_mm        41499 non-null  float64
#  47  High_Winds_Storms                      41442 non-null  float64
#  48  Simulated_Wind_Load_Pressure_kPa       41476 non-null  float64
#  49  Abnormal_Traffic_Load_Surges           41437 non-null  float64
#  50  Simulated_Localized_Stress_Index       41482 non-null  float64
#  51  Energy_Harvesting_Potential_W          41471 non-null  float64
#  52  Estimated_Repair_Cost_USD_incremental  41429 non-null  float64
#  53  Carbon_Footprint_tCO2e_incremental     41476 non-null  float64
# dtypes: float64(51), object(3)
# memory usage: 17.8+ MB

# %%
data.isna().sum()
# Out:
# Timestamp                                    0
# Strain_microstrain                        1821
# Deflection_mm                             1733
# Vibration_ms2                             1722
# Tilt_deg                                  1753
# Displacement_mm                           1727
# Crack_Propagation_mm                      1706
# Corrosion_Level_percent                   1669
# Cable_Member_Tension_kN                   1741
# Bearing_Joint_Forces_kN                   1685
# Fatigue_Accumulation_au                   1704
# Modal_Frequency_Hz                        1719
# Temperature_C                             1743
# Humidity_percent                          1783
# Wind_Speed_ms                             1726
# Wind_Direction_deg                        1768
# Precipitation_mmh                         1687
# Water_Level_m                             1687
# Seismic_Activity_ms2                      1693
# Solar_Radiation_Wm2                       1728
# Air_Quality_Index_AQI                     1739
# Soil_Settlement_mm                        1698
# Vehicle_Load_tons                         1756
# Traffic_Volume_vph                        1744
# Pedestrian_Load_pph                       1727
# Impact_Events_g                           1718
# Dynamic_Load_Distribution_percent         1661
# Axle_Counts_pmin                          1700
# Structural_Health_Index_SHI               1700
# Anomaly_Detection_Score                   1706
# Energy_Dissipation_au                     1694
# Acoustic_Emissions_levels                 1721
# Visual_Analysis_Defect_Score              1735
# Electrical_Resistance_ohms                1746
# Bridge_Mood_Meter                         1710
# Localized_Strain_Hotspot                  1754
# Vibration_Anomaly_Location               34155
# SHI_Predicted_24h_Ahead                   1662
# SHI_Predicted_7d_Ahead                    1646
# SHI_Predicted_30d_Ahead                   1738
# Probability_of_Failure_PoF                1744
# Maintenance_Alert                         1696
# Flood_Event_Flag                          1743
# Simulated_Water_Flow_m3s                  1706
# Soil_Saturation_percent                   1747
# Landslide_Ground_Movement                 1765
# Simulated_Slope_Displacement_mm           1701
# High_Winds_Storms                         1758
# Simulated_Wind_Load_Pressure_kPa          1724
# Abnormal_Traffic_Load_Surges              1763
# Simulated_Localized_Stress_Index          1718
# Energy_Harvesting_Potential_W             1729
# Estimated_Repair_Cost_USD_incremental     1771
# Carbon_Footprint_tCO2e_incremental        1724
# dtype: int64

# %%
bridge_data = data[[
    "Strain_microstrain",
    "Deflection_mm",
    "Displacement_mm",
    "Localized_Strain_Hotspot",
    "Vibration_ms2",
    "Seismic_Activity_ms2",
    "Impact_Events_g",
    "Modal_Frequency_Hz",
    "Energy_Dissipation_au",
    "Temperature_C",
    "Structural_Health_Index_SHI"
]]
bridge_data
# Out:
#        Strain_microstrain  Deflection_mm  Displacement_mm  \
# 0                     NaN      12.663104        22.576518
# 1              599.936448      12.235297        21.202649
# 2              573.878472      12.447144              NaN
# 3              550.457302      12.554883        21.551945
# 4              572.829960      12.598818        21.711292
# ...                   ...            ...              ...
# 43195          571.243037      12.455028        20.842984
# 43196          567.188954      12.526918        19.966430
# 43197          564.514503      12.085239        21.452594
# 43198          535.732467      12.585243        21.658293
# 43199          562.674849      12.874938        21.489846
#
#        Localized_Strain_Hotspot  Vibration_ms2  Seismic_Activity_ms2  \
# 0                           0.0       1.275955         -5.732291e-06
# 1                           0.0       0.716857          7.162631e-06
# 2                           0.0       0.834753         -1.061253e-06
# 3                           0.0       1.004917          5.572270e-06
# 4                           0.0       1.176253          6.600767e-08
# ...                         ...            ...                   ...
# 43195                       0.0       1.014705          3.784471e-06
# 43196                       0.0       0.977208         -2.434413e-06
# 43197                       0.0       0.985721         -5.141186e-06
# 43198                       0.0       1.053336         -3.070826e-06
# 43199                       0.0       1.201835         -3.348795e-06
#
#        Impact_Events_g  Modal_Frequency_Hz  Energy_Dissipation_au  \
# 0         4.631398e-06            1.924556               0.016281
# 1         1.555199e-06            1.779174               0.021419
# 2         1.015520e-05            1.934703               0.028388
# 3         4.094442e-06            1.916426               0.038486
# 4        -2.288449e-06            1.893920               0.052322
# ...                ...                 ...                    ...
# 43195     1.605901e-06            1.828899               0.103265
# 43196              NaN            1.909683               0.100680
# 43197    -1.394526e-05            1.918500               0.103688
# 43198    -2.136437e-07            1.994553               0.108462
# 43199    -4.812608e-06            1.987467               0.108458
#
#        Temperature_C  Structural_Health_Index_SHI
# 0           9.970055                     0.859543
# 1          10.143691                     0.863882
# 2          10.119537                     0.862827
# 3          11.240298                     0.861611
# 4           9.195454                     0.857407
# ...              ...                          ...
# 43195      10.606595                     0.857921
# 43196      10.175937                     0.858214
# 43197      10.000999                     0.861265
# 43198      10.007617                     0.859143
# 43199       9.843861                     0.853232
#
# [43200 rows x 11 columns]

# %%
bridge_data.shape
# Out:
# (43200, 11)

# %%
bridge_data.isnull().sum()
# Out:
# Strain_microstrain             1821
# Deflection_mm                  1733
# Displacement_mm                1727
# Localized_Strain_Hotspot       1754
# Vibration_ms2                  1722
# Seismic_Activity_ms2           1693
# Impact_Events_g                1718
# Modal_Frequency_Hz             1719
# Energy_Dissipation_au          1694
# Temperature_C                  1743
# Structural_Health_Index_SHI    1700
# dtype: int64

# %%
input_data = bridge_data.drop(columns=['Structural_Health_Index_SHI'])
X = input_data.fillna(input_data.mean())
Y = bridge_data['Structural_Health_Index_SHI']
Y = Y.fillna(Y.mean())

# %%
standardScaler = StandardScaler()
standard_X = standardScaler.fit_transform(X)
standard_X
# Out:
# array([[-3.30094121e-16, -6.62564791e-01, -7.96750993e-02, ...,
#          2.97633571e-01, -2.07537932e-01, -6.48342660e-01],
#        [-7.31733502e-01, -7.76753113e-01, -9.41061163e-01, ...,
#         -1.18205667e+00, -2.03387467e-01, -6.25949177e-01],
#        [-8.07393839e-01, -7.20207959e-01, -2.22747403e-15, ...,
#          4.00906337e-01, -1.97759550e-01, -6.29064312e-01],
#        ...,
#        [-8.34582485e-01, -8.16806131e-01, -7.84350697e-01, ...,
#          2.35995341e-01, -1.36942264e-01, -6.44351909e-01],
#        [-9.18152237e-01, -6.83347122e-01, -6.55382238e-01, ...,
#          1.01004562e+00, -1.33086368e-01, -6.43498443e-01],
#        [-8.39923991e-01, -6.06023052e-01, -7.60994714e-01, ...,
#          9.37925919e-01, -1.33089784e-01, -6.64617765e-01]])

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

# %% [markdown]
# For training model

# %%
model = RandomForestRegressor(n_estimators=200, max_depth=15, random_state=42)

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=15, n_estimators=200, random_state=42)

# %%
x_test
# Out:
#        Strain_microstrain  Deflection_mm  Displacement_mm  \
# 15158          984.050457      16.082198        23.959808
# 17980          921.898400      16.458668        22.754658
# 14207          457.858002       8.727753        21.931385
# 42340         1331.478746      22.716674        26.261156
# 22155         1417.765843      22.353035        24.250625
# ...                   ...            ...              ...
# 165            620.900854      15.265018        20.164991
# 30402          639.356585      15.545345        21.851614
# 8902           693.217783      16.837735        21.746068
# 19293         1296.507880      22.029483        25.012460
# 39265          704.200579      17.370470        22.405639
#
#        Localized_Strain_Hotspot  Vibration_ms2  Seismic_Activity_ms2  \
# 15158                       0.0       1.466651         -2.700144e-06
# 17980                       0.0       1.534001          1.333243e-06
# 14207                       0.0       0.888302         -2.520297e-06
# 42340                       0.0       1.423917          2.651300e-06
# 22155                       0.0       1.888987          7.116124e-06
# ...                         ...            ...                   ...
# 165                         0.0       0.753349         -9.940584e-07
# 30402                       0.0       1.086448         -9.804755e-06
# 8902                        0.0       0.764998         -1.236812e-06
# 19293                       0.0       1.749846         -2.699651e-06
# 39265                       0.0       1.230351          1.783340e-04
#
#        Impact_Events_g  Modal_Frequency_Hz  Energy_Dissipation_au  \
# 15158     1.967864e-06            1.818377               0.171439
# 17980    -2.709368e-06            1.872317               0.169074
# 14207     1.993567e-06            1.852048               0.096654
# 42340    -6.523587e-07            1.972264               0.296117
# 22155    -1.007927e-05            1.978931               0.291616
# ...                ...                 ...                    ...
# 165       9.497596e-06            1.950076               0.099567
# 30402     4.009954e-06            1.985870               0.116922
# 8902      5.512265e-06            1.953407               0.273241
# 19293     6.947533e-06            1.895801               0.281288
# 39265     5.524291e-08            2.034392               0.108093
#
#        Temperature_C
# 15158      24.518991
# 17980      21.810472
# 14207      21.826191
# 42340      12.910188
# 22155      12.088959
# ...              ...
# 165         5.322817
# 30402       1.155645
# 8902        8.903091
# 19293      15.654178
# 39265       3.844735
#
# [8640 rows x 10 columns]

# %%
y_prediction = model.predict(x_test)

# %%
mae = mean_absolute_error(y_test, y_prediction) #mean absolute error
rmse = np.sqrt(mean_squared_error(y_test, y_prediction)) #root mean squared error
r2 = r2_score(y_test, y_prediction) #r2 score

# %%
print(mae, rmse, r2)
# Out:
# 0.0038702093093097123 0.011372574594139123 0.955024525277861
